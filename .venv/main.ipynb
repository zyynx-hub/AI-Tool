# %%
import pandas as pd
main = pd.read_excel(r"C:\Users\Robin\OneDrive\Save\HBO\Semester 4\Sprint 3\Requirements\OpgeschoondeOutputEnquete.xlsx")
main.head()
# Out:
#                                                  Rol  \
# 0  Mijn rol is Senior Talent Adviseur op het gebi...
# 1  Recruiter (van inventarisatie van de ontstane ...
# 2                                    Account manager
# 3                                 Recruitmentmanager
# 4  Mijn rol binnen het wervingsproces zit in het ...
#
#                                   Voorselectieproces  \
# 0  In mijn rol als IT-recruiter binnen de detache...
# 1  1. Sourcen/searchen (zoeken naar geschikte kan...
# 2  Daar hou ik me niet mee bezig als account mana...
# 3  Screenen inschrijvingen website, Linkedin prof...
# 4  Een klant heeft eisen en wensen voor een kandi...
#
#                                  Tijdrovende stappen  \
# 0  - Grote hoeveelheid (niet-relevante) cv’s door...
# 1  Het meeste tijd (en meest eentonig werk) is vo...
# 2                                                nvt
# 3                    Zoeken van geschikte kandidaten
# ...
